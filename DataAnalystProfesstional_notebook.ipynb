# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# # **Report**
# #
# 1. **data validation and cleaning steps :**
# 1.1 check for null values and found revenue have some. Those were replaced by mean value.
# 1.2 check for years_as_customer. Give the company started 1984, largest value of  years_as_customer should be 2024-1984 = 40. All value exceeds that were replaced by 40.
# 1.3 standardized sales method. em + call should be email + call. And upper cases were all standardized to lower case.
# ----------------------------------
# 2. **Exploratory Analysis:**
# 2.1 two graphics showing single variables only to demonstrate the characteristics of data
# ![revenuedist](revenuedist.png)
#
# ![nb_visitdist](nb_visitdist.png)
# 2.2 one graphic showing two or more variables to represent the relationship between features
# ![Avgrevbysalesmethod](Avgrevbysalesmethod.png)
# ![Avgrevenuebynbvisit](Avgrevenuebynbvisit.png)
# ----------------------------------
# 2.3 *Findings*
# - Revenue have wide-range distribution. From the investigation, each customer have different characteristic in buying, which leads to different number of products buying and different revenues.
#
# - number of site visit (nb_visit) have an approximately normal distribution.
#
# - Total revenues by sales method of email is the largest  among 3 methods. However, average revenue per customer by sales method of email+call is the largest. It can be interpretted that email+call are most likely to contribute to largest amount of revenues per customer, on average.
#
#             total revenue
#         -  call        244,565.73
#         -  email       723,418.47
#         -  email+call  441,040.01
#
#            Average revenue per customer
#         -  call        49.29
#         -  email       96.90
#         -  email+call  171.48
#
#             Total sample customers
#         -  call        4962
#         -  email       7466
#         -  email+call  2572
#
#
#
#
#
# - Average revenue per customers by nb_visit is the best when nb_visit is around 37 times, after that it dropped.Therefore, we can interpret that customers who visit website around 37 times are most likely to contribute to high revenues.
#
# ----------------------------------
# 3. **Metrics for business to monitor**
# - Average revenue per customer by sales method
# - Average revenue per customer by number of sites visit
# ----------------------------------
# 4. **Initial value of average:**
#
#
# 4.1 Average revenue per customer by sales method:
# - call    =    49.29
# - email   =    96.90
# - email+call = 171.48
# ----------------------------------
# 4.2 Site Visits Revenue Statistics:
#
#
#
#     nb_site_visits  revenue
#                12    40.95
#                13    51.33
#                14    72.24
#                15    70.99
#                16    61.67
#                17    67.19
#                18    66.23
#                19    71.78
#                20    74.57
#                21    77.52
#                22    82.42
#                23    85.37
#                24    89.71
#                25    91.97
#                26    96.69
#                27   101.84
#                28   104.27
#                29   112.09
#                30   115.21
#                31   120.54
#                32   128.08
#                33   122.26
#                34   139.15
#                35   149.87
#                36   156.49
#                37   167.78
#                41    93.94
# ----------------------------------
# 4.3 **Reason of choosing these metrics:**
# These 2 metrics should be monitored to optimize the process to get higher revenues. For example, if we found that the Average revenue per customer by call is really low, we may investigate further what's wrong and improve it. Or in the future if we have various sales methods we may decide to cut down some methods that don't bring high revenues.
# Also, investigating average revenue per customer by number of sites visit can help us to know how many times customers take until buying the products. If we found some customers visit website a lot of time but turn out buying less, we can investigate further and make improvements as well. For example, customers who visit the website 41 times contribute to around -40% in revenues comparing to 37 times visitors. We may investigate further what's wrong.
# ----------------------------------
# 5. **Final summary and recommendations:**
# Business should focus more on email+call as a sales method. From the data, it can be seen that this method bring the highest amount of revenues on average, even though the sample size is lowest.
# Also, business could investigate more on customers who visit the website more than 37 times on why they contribute to less revenues.
# ----------------------------------

# %%
import pandas as pd
data = pd.read_csv('product_sales.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   week               15000 non-null  int64
#  1   sales_method       15000 non-null  object
#  2   customer_id        15000 non-null  object
#  3   nb_sold            15000 non-null  int64
#  4   revenue            13926 non-null  float64
#  5   years_as_customer  15000 non-null  int64
#  6   nb_site_visits     15000 non-null  int64
#  7   state              15000 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 937.6+ KB

# %%
data.describe()
# Out:
#                week       nb_sold  ...  years_as_customer  nb_site_visits
# count  15000.000000  15000.000000  ...       15000.000000    15000.000000
# mean       3.098267     10.084667  ...           4.965933       24.990867
# std        1.656420      1.812213  ...           5.044952        3.500914
# min        1.000000      7.000000  ...           0.000000       12.000000
# 25%        2.000000      9.000000  ...           1.000000       23.000000
# 50%        3.000000     10.000000  ...           3.000000       25.000000
# 75%        5.000000     11.000000  ...           7.000000       27.000000
# max        6.000000     16.000000  ...          63.000000       41.000000
#
# [8 rows x 5 columns]

# %%
# Display unique values for each column
for column in data.columns:
    unique_values = data[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values[:])  
    print(f"Total unique values: {len(unique_values)}\n")
# Out:
# Unique values in column 'week':
# [2 6 5 4 3 1]
# Total unique values: 6
#
# Unique values in column 'sales_method':
# ['Email' 'Email + Call' 'Call' 'em + call' 'email']
# Total unique values: 5
#
# Unique values in column 'customer_id':
# ['2e72d641-95ac-497b-bbf8-4861764a7097'
#  '3998a98d-70f5-44f7-942e-789bb8ad2fe7'
#  'd1de9884-8059-4065-b10f-86eef57e4a44' ...
#  '839653cb-68c9-48cb-a097-0a5a3b2b298b'
#  'e4dad70a-b23b-407c-8bd3-e32ea00fae17'
#  '4e077235-7c17-4054-9997-7a890336a214']
# Total unique values: 15000
#
# Unique values in column 'nb_sold':
# [10 15 11  9 13  8 12  7 14 16]
# Total unique values: 10
#
# Unique values in column 'revenue':
# [   nan 225.47  52.55 ...  44.34  45.01  64.9 ]
# Total unique values: 6744
#
# Unique values in column 'years_as_customer':
# [ 0  1  6  3 10  9  7  4  2 20  8  5 17 36 15 14 19 13 12 11 30 24 22 18
#  26 23 32 16 39 25 33 21 31 27 34 28 29 35 38 37 63 47]
# Total unique values: 42
#
# Unique values in column 'nb_site_visits':
# ...

# %%
data[data['revenue'].isnull()]
# Out:
#        week  sales_method  ... nb_site_visits         state
# 0         2         Email  ...             24       Arizona
# 3         4         Email  ...             25       Indiana
# 16        2         Email  ...             30  Pennsylvania
# 17        6  Email + Call  ...             24     Wisconsin
# 28        5         Email  ...             32       Florida
# ...     ...           ...  ...            ...           ...
# 14951     5          Call  ...             25      Virginia
# 14957     1          Call  ...             23      Illinois
# 14970     4  Email + Call  ...             25    Washington
# 14992     5     em + call  ...             34      New York
# 14999     5  Email + Call  ...             25      Illinois
#
# [1074 rows x 8 columns]

# %%
data['revenue'] = data['revenue'].fillna(93.935)

# %%
# Replace all values in 'years_as_customer' greater than 40 with 40
data.loc[data['years_as_customer'] > 40, 'years_as_customer'] = 40

# %%
 import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for 'revenue'
plt.figure(figsize=(10, 6))
sns.histplot(data['revenue'], kde=True, bins=30, color='blue')
plt.title('Distribution of Revenue')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.show()

# Histogram for 'nb_site_visits'
plt.figure(figsize=(10, 6))
sns.histplot(data['nb_site_visits'], kde=True, bins=30, color='green')
plt.title('Distribution of Number of Site Visits')
plt.xlabel('Number of Site Visits')
plt.ylabel('Frequency')
plt.show()

# %%
# Standardize the 'sales_method' column
data['sales_method'] = data['sales_method'].str.lower().str.strip()

# Replace 'em + call' and other possible variants
data['sales_method'] = data['sales_method'].replace(['em + call', 'em+call', 'email + call'], 'email+call')

# Check for unique sales methods to confirm standardization
print("Unique sales methods after standardization:", data['sales_method'].unique())

import seaborn as sns
# Group and calculate revenue for each sales method
sales_method_revenue = data.groupby('sales_method')['revenue'].sum().reset_index()

# Group and calculate revenue for each state
state_revenue = data.groupby('state')['revenue'].sum().reset_index()

# Group and calculate revenue by number of site visits
site_visits_revenue = data.groupby('nb_site_visits')['revenue'].sum().reset_index()

# Plot Revenue by Sales Method
plt.figure(figsize=(10, 5))
sns.barplot(data=sales_method_revenue, x='sales_method', y='revenue', palette='Blues_d')
plt.title('Revenue by Sales Method')
plt.xlabel('Sales Method')
plt.ylabel('Revenue')
plt.show()

# # Plot Revenue by State
# plt.figure(figsize=(10, 5))
# sns.barplot(data=state_revenue, x='state', y='revenue', palette='Greens_d')
# plt.title('Revenue by State')
# plt.xlabel('State')
# plt.ylabel('Revenue')
# plt.show()

# Plot Revenue by Number of Site Visits
plt.figure(figsize=(10, 5))
sns.lineplot(data=site_visits_revenue, x='nb_site_visits', y='revenue', marker='o', color='orange')
plt.title('Revenue by Number of Site Visits')
plt.xlabel('Number of Site Visits')
plt.ylabel('Revenue')
plt.show()

# Identify Best Sales Method
best_sales_method = sales_method_revenue.loc[sales_method_revenue['revenue'].idxmax()]
print(f"The best sales method is {best_sales_method['sales_method']} with revenue of {best_sales_method['revenue']}.")
# Out:
# Unique sales methods after standardization: ['email' 'email+call' 'call']
# The best sales method is email with revenue of 723418.47.

# %%
# Get top 3 states by revenue
top_3_states = state_revenue.sort_values(by='revenue', ascending=False).head(3)

# Plot Revenue for Top 3 States
plt.figure(figsize=(8, 5))
sns.barplot(data=top_3_states, x='state', y='revenue', palette='Greens_d')
plt.title('Top 3 States by Revenue')
plt.xlabel('State')
plt.ylabel('Revenue')
plt.show()

# %%
# Group and calculate mean and count of revenue for each sales method
sales_method_revenue_stats = data.groupby('sales_method')['revenue'].agg(['sum','mean', 'count']).reset_index()

# Group and calculate mean and count of revenue for each state
state_revenue_stats = data.groupby('state')['revenue'].agg(['sum','mean', 'count']).reset_index()

# Group and calculate mean and count of revenue by number of site visits
site_visits_revenue_stats = data.groupby('nb_site_visits')['revenue'].agg(['sum','mean', 'count']).reset_index()

# Display results
print("Sales Method Revenue Statistics:")
print(sales_method_revenue_stats)

print("\nState Revenue Statistics:")
print(state_revenue_stats)

print("\nSite Visits Revenue Statistics:")
print(site_visits_revenue_stats)
# Out:
# Sales Method Revenue Statistics:
#   sales_method         sum        mean  count
# 0         call  244565.725   49.287732   4962
# 1        email  723418.470   96.895054   7466
# 2   email+call  441040.005  171.477451   2572
#
# State Revenue Statistics:
#              state         sum        mean  count
# 0          Alabama   20711.080   96.780748    214
# 1           Alaska    3669.665   91.741625     40
# 2          Arizona   29643.490   92.347321    321
# 3         Arkansas   12110.470   91.745985    132
# 4       California  173534.245   92.699917   1872
# 5         Colorado   21236.310   92.331783    230
# 6      Connecticut   17479.870   97.652905    179
# 7         Delaware    3438.365  101.128382     34
# 8          Florida   84978.680   94.002965    904
# 9          Georgia   46150.525   94.377352    489
# 10          Hawaii    6995.325   97.157292     72
# 11           Idaho    6306.195  101.712823     62
# 12        Illinois   56500.685   91.573233    617
# ...

# %%
# Group and calculate revenue for each sales method
sales_method_revenue_mean = data.groupby('sales_method')['revenue'].mean().reset_index()

# Group and calculate revenue for each state
state_revenue_mean = data.groupby('state')['revenue'].mean().reset_index()

# Group and calculate revenue by number of site visits
site_visits_revenue_mean = data.groupby('nb_site_visits')['revenue'].mean().reset_index()

# Plot Revenue by Sales Method
plt.figure(figsize=(10, 5))
sns.barplot(data=sales_method_revenue_mean, x='sales_method', y='revenue', palette='Blues_d')
plt.title('Average Revenue by Sales Method')
plt.xlabel('Sales Method')
plt.ylabel('Revenue')
plt.show()


# Plot Revenue by Number of Site Visits
plt.figure(figsize=(10, 5))
sns.lineplot(data=site_visits_revenue_mean, x='nb_site_visits', y='revenue', marker='o', color='orange')
plt.title('Average Revenue by Number of Site Visits')
plt.xlabel('Number of Site Visits')
plt.ylabel('Revenue')
plt.show()

# Identify Best Sales Method
best_sales_method = sales_method_revenue_mean.loc[sales_method_revenue_mean['revenue'].idxmax()]
print(f"The best sales method is {best_sales_method['sales_method']} with revenue of {best_sales_method['revenue']}.")
# Out:
# The best sales method is email+call with revenue of 171.47745139968896.

# %%
# Calculate total revenue per customer
data['total_revenue_per_customer'] = data['revenue'] / data['nb_sold']

# Group by customer_id and calculate the average revenue per product
avg_revenue_per_customer = data.groupby('customer_id')['total_revenue_per_customer'].mean().reset_index()

# Check the first few rows of the new data
avg_revenue_per_customer.head()
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the distribution of average revenue per customer per product
plt.figure(figsize=(10, 6))
sns.histplot(avg_revenue_per_customer['total_revenue_per_customer'], kde=True, bins=30, color='purple')
plt.title('Distribution of Average Revenue per Customer per Product')
plt.xlabel('Average Revenue per Customer per Product')
plt.ylabel('Frequency')
plt.show()

# Optionally, you can use a boxplot to see the spread and outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=avg_revenue_per_customer, x='total_revenue_per_customer', color='lightblue')
plt.title('Box Plot of Average Revenue per Customer per Product')
plt.xlabel('Average Revenue per Customer per Product')
plt.show()

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation
